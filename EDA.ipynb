# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('C:/Users/dell/Downloads/vehicle price prediction/imputed_data.csv')
df.sample(4)
# Out:
#         year       make             model    trim      body transmission  \
# 480876  2009       Ford  f-350 super duty  Lariat  crew cab    automatic
# 497138  2003  Chevrolet            impala    Base     sedan    automatic
# 223380  2011     Nissan            sentra   2.0 S     sedan    automatic
# 41916   2013     Toyota            avalon     XLE     sedan    automatic
#
#        state  condition  odometer  color interior  \
# 480876    tx       19.0   34486.0  white      tan
# 497138    fl       34.0   94605.0   gold     gray
# 223380    il       22.0   40128.0  black    beige
# 41916     tx        2.0   33430.0  white     gray
#
#                                      seller      mmr  sellingprice  \
# 480876             j & j auto & truck sales  31700.0       28000.0
# 497138         starling chevrolet buick gmc   1750.0        1800.0
# 223380  nissan motor acceptance corporation   8925.0        7700.0
# 41916                             hertz/tra  19000.0       13300.0
#
# ...

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (548535, 15)
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df.sample(3)
# Out:
#         year       make     model  trim   body transmission state  condition  \
# 314551  2009  Chevrolet    cobalt    LT  sedan    automatic    fl       34.0
# 459083  2004    Hyundai  santa fe  Base    suv    automatic    ms       21.0
# 199065  2013     Nissan    altima   2.5  sedan    automatic    il       23.0
#
#         odometer     color interior                                   seller  \
# 314551   95095.0     beige    black  remarketing by ge/summit financial corp
# 459083  137176.0  burgundy     gray                    dt credit corporation
# 199065   47850.0    silver    black                    the hertz corporation
#
#             mmr  sellingprice                                 saledate
# 314551   3925.0        4000.0  Tue Feb 17 2015 03:05:00 GMT-0800 (PST)
# 459083   1725.0        1400.0  Thu May 28 2015 03:15:00 GMT-0700 (PDT)
# 199065  13000.0       10800.0  Thu Mar 05 2015 02:30:00 GMT-0800 (PST)

# %% [markdown]
# seller and sale date probably use less

# %%
df_cat=df.select_dtypes(include='object')
df_cat.drop(columns=['saledate','seller'], inplace=True)
df_cat.sample(2)
# Out:
#           make    model               trim   body transmission state   color  \
# 369633   Honda    civic                 LX  sedan    automatic    il    gray
# 335668  Subaru  outback  2.5i Premium PZEV  wagon    automatic    nj  silver
#
#        interior
# 369633    beige
# 335668    black

# %%
for col in df_cat:
    print(df_cat[col].value_counts().to_string())
    print('*****************************')
# Out:
# make
# Ford             93554
# Chevrolet        60197
# Nissan           53946
# Toyota           39871
# Dodge            30710
# Honda            27206
# Hyundai          21816
# BMW              20719
# Kia              18077
# Chrysler         17276
# Mercedes-Benz    17141
# Jeep             15372
# Infiniti         15305
# Volkswagen       12581
# Lexus            11861
# GMC              10613
# Mazda             8362
# Cadillac          7519
# Acura             5901
# Audi              5869
# Lincoln           5757
# Buick             5107
# Subaru            5043
# Ram               4574
# Pontiac           4497
# Mitsubishi        4140
# Volvo             3788
# MINI              3224
# Saturn            2841
# Mercury           1992
# Land Rover        1735
# Scion             1687
# Jaguar            1419
# Porsche           1383
# Suzuki            1073
# FIAT               865
# HUMMER             805
# Saab               484
# ford               443
# ...

# %%
make_list=df['make'].value_counts().index.tolist()
i=1
a=[]
for j in make_list:
    print(f'{i}--->  {j}')
    a.append(j)
    if i>=35:
        print('list finidh')
        break
    i=i+1
make_list=a
make_list= list(map(str.lower,make_list))
print(make_list)
# Out:
# 1--->  Ford
# 2--->  Chevrolet
# 3--->  Nissan
# 4--->  Toyota
# 5--->  Dodge
# 6--->  Honda
# 7--->  Hyundai
# 8--->  BMW
# 9--->  Kia
# 10--->  Chrysler
# 11--->  Mercedes-Benz
# 12--->  Jeep
# 13--->  Infiniti
# 14--->  Volkswagen
# 15--->  Lexus
# 16--->  GMC
# 17--->  Mazda
# 18--->  Cadillac
# 19--->  Acura
# 20--->  Audi
# 21--->  Lincoln
# 22--->  Buick
# 23--->  Subaru
# 24--->  Ram
# 25--->  Pontiac
# 26--->  Mitsubishi
# 27--->  Volvo
# 28--->  MINI
# 29--->  Saturn
# 30--->  Mercury
# 31--->  Land Rover
# 32--->  Scion
# 33--->  Jaguar
# 34--->  Porsche
# 35--->  Suzuki
# list finidh
# ['ford', 'chevrolet', 'nissan', 'toyota', 'dodge', 'honda', 'hyundai', 'bmw', 'kia', 'chrysler', 'mercedes-benz', 'jeep', 'infiniti', 'volkswagen', 'lexus', 'gmc', 'mazda', 'cadillac', 'acura', 'audi', 'lincoln', 'buick', 'subaru', 'ram', 'pontiac', 'mitsubishi', 'volvo', 'mini', 'saturn', 'mercury', 'land rover', 'scion', 'jaguar', 'porsche', 'suzuki']

# %% [markdown]
# make column

# %% [markdown]
# top 35 companyes ki list rakhi banki values ko other me change kr diay

# %%
print(make_list)
df_cat['make']=df_cat['make'].str.lower()
print(df_cat['make'].sample(5))
df_cat['make']=df_cat['make'].apply(lambda x: x  if x in make_list else 'other' )

print(df_cat['make'].nunique())
print(df_cat['make'].value_counts())
# Out:
# ['ford', 'chevrolet', 'nissan', 'toyota', 'dodge', 'honda', 'hyundai', 'bmw', 'kia', 'chrysler', 'mercedes-benz', 'jeep', 'infiniti', 'volkswagen', 'lexus', 'gmc', 'mazda', 'cadillac', 'acura', 'audi', 'lincoln', 'buick', 'subaru', 'ram', 'pontiac', 'mitsubishi', 'volvo', 'mini', 'saturn', 'mercury', 'land rover', 'scion', 'jaguar', 'porsche', 'suzuki']
# 64659      chevrolet
# 402641    mitsubishi
# 345171          fiat
# 335033          ford
# 297568           bmw
# Name: make, dtype: object
# 36
# make
# ford             93997
# chevrolet        60587
# nissan           54017
# toyota           39966
# dodge            30955
# honda            27351
# hyundai          21836
# bmw              20793
# kia              18084
# chrysler         17485
# mercedes-benz    17141
# jeep             15483
# infiniti         15305
# volkswagen       12605
# lexus            11980
# gmc              10638
# mazda             8508
# cadillac          7629
# acura             5926
# ...

# %%
group=df_cat.groupby('make')['model'].value_counts()
pd.set_option('display.max_rows',None)
group
# Out:
# make           model
# acura          tl                                2135
#                mdx                               1585
#                tsx                               1119
#                rdx                                420
#                rsx                                151
#                ilx                                140
#                rl                                 131
#                cl                                  97
#                integra                             44
#                zdx                                 39
#                tsx sport wagon                     36
#                rlx                                 17
#                legend                               9
#                el                                   2
#                tlx                                  1
# audi           a4                                2277
#                a6                                 833
# ...

# %% [markdown]
# to hmne yaha ye kiya h ki jaha jaha values bht km thi make ya company ke column me to jhmne ujske features ko reduce krne ke liye kewal 35 uniqe values rakhi and banki values ko other me daal diya and other ke jon model the unme bhi opther daal diya            other                        3681             ye wo value h or jo pridiction hoga banki values ke bases p rhoga esse value robust hop jayenge and model overfit na hogaa

# %%
df_cat['model'] = df_cat.apply(lambda row: 'other' if row['make'] == 'other' else row['model'], axis=1)
df_cat['model'].value_counts()
# Out:
# model
# altima                      19349
# f-150                       14479
# fusion                      12946
# camry                       12549
# escape                      11893
# focus                       10399
# accord                       9155
# 3 series                     8290
# impala                       7957
# grand caravan                7941
# explorer                     7779
# civic                        7440
# g sedan                      7417
# corolla                      7360
# malibu                       7146
# sonata                       6914
# maxima                       6611
# silverado 1500               6362
# cruze                        6349
# elantra                      6265
# town and country             5994
# edge                         5915
# rogue                        5589
# sentra                       5465
# c-class                      5397
# mustang                      4950
# equinox                      4917
# ...

# %%
df_cat.sample(5)
# Out:
#                  make    model  trim   body transmission state   color  \
# 452905  mercedes-benz  c-class  C250  coupe    automatic    tx    blue
# 443137            kia      rio    LX  sedan    automatic    tn   black
# 333248            kia  sorento    EX    suv    automatic    fl  silver
# 110775           ford   escape   XLT    suv    automatic    nj     red
# 278879           ford    focus     S  sedan    automatic    mo   black
#
#        interior
# 452905      tan
# 443137      tan
# 333248    black
# 110775        —
# 278879    black

# %%
df_cat['trim']=df_cat['trim'].str.lower()
df_cat['trim'].value_counts()
# Out:
# trim
# base                                              55916
# se                                                43694
# lx                                                20788
# limited                                           18371
# lt                                                17023
# xlt                                               16745
# ls                                                13539
# le                                                12929
# gls                                               12336
# s                                                 12280
# 2.5 s                                             11212
# sxt                                               11206
# touring                                           11152
# sel                                               10480
# sport                                              9688
# ex                                                 9511
# 2.5                                                6908
# ...

# %%
make_list_trim=df['trim'].value_counts().index.tolist()
i=1
a=[]
for j in make_list_trim:
    print(f'{i}--->  {j}')
    a.append(j)
    if i>=40:
        print('list finidh')
        break
    i=i+1
make_list_trim=a
make_list_trim= list(map(str.lower,make_list_trim))
print(make_list_trim)
print(len(make_list_trim))
# Out:
# 1--->  Base
# 2--->  SE
# 3--->  LX
# 4--->  Limited
# 5--->  LT
# 6--->  XLT
# 7--->  LS
# 8--->  LE
# 9--->  GLS
# 10--->  S
# 11--->  2.5 S
# 12--->  SXT
# 13--->  Touring
# 14--->  SEL
# 15--->  EX
# 16--->  Sport
# 17--->  2.5
# 18--->  SLT
# 19--->  SV
# 20--->  EX-L
# 21--->  LTZ
# 22--->  XL
# 23--->  G37x
# 24--->  V6
# 25--->  3.5 SV
# 26--->  SL
# 27--->  328i
# 28--->  Lariat
# 29--->  Titanium
# 30--->  1LT
# 31--->  G37 Journey
# 32--->  LT Fleet
# 33--->  Laredo
# 34--->  LS Fleet
# 35--->  SLE
# 36--->  Luxury
# 37--->  SE PZEV
# 38--->  GT
# 39--->  Premium
# 40--->  2LT
# list finidh
# ['base', 'se', 'lx', 'limited', 'lt', 'xlt', 'ls', 'le', 'gls', 's', '2.5 s', 'sxt', 'touring', 'sel', 'ex', 'sport', '2.5', 'slt', 'sv', 'ex-l', 'ltz', 'xl', 'g37x', 'v6', '3.5 sv', 'sl', '328i', 'lariat', 'titanium', '1lt', 'g37 journey', 'lt fleet', 'laredo', 'ls fleet', 'sle', 'luxury', 'se pzev', 'gt', 'premium', '2lt']
# 40

# %%
print(make_list_trim)
df_cat['trim']=df_cat['trim'].str.lower()
print(df_cat['make'].sample(5))
df_cat['trim']=df_cat['trim'].apply(lambda x: x  if x in make_list_trim else 'other' )

print(df_cat['trim'].nunique())
print(df_cat['trim'].value_counts())
# Out:
# ['base', 'se', 'lx', 'limited', 'lt', 'xlt', 'ls', 'le', 'gls', 's', '2.5 s', 'sxt', 'touring', 'sel', 'ex', 'sport', '2.5', 'slt', 'sv', 'ex-l', 'ltz', 'xl', 'g37x', 'v6', '3.5 sv', 'sl', '328i', 'lariat', 'titanium', '1lt', 'g37 journey', 'lt fleet', 'laredo', 'ls fleet', 'sle', 'luxury', 'se pzev', 'gt', 'premium', '2lt']
# 540884       land rover
# 487118           nissan
# 266220             ford
# 23908             dodge
# 204483    mercedes-benz
# Name: make, dtype: object
# 41
# trim
# other          176000
# base            55916
# se              43694
# lx              20788
# limited         18371
# lt              17023
# xlt             16745
# ls              13539
# le              12929
# gls             12336
# s               12280
# 2.5 s           11212
# sxt             11206
# touring         11152
# sel             10480
# sport            9688
# ex               9511
# 2.5              6908
# slt              6014
# sv               5700
# ...

# %% [markdown]
# uper wale me trim ka kaamkr diya top 40 values accuare kr li banmion tujm dekh lo

# %% [markdown]
# ab hoga body pr kaam mtlb body column pr kaam

# %%
df_cat.groupby('model')['body'].value_counts()
# Out:
# model                     body
# 1                         sedan                          1
# 1 series                  convertible                  223
#                           coupe                        182
# 1500                      crew cab                    1462
#                           quad cab                    1441
#                           regular cab                  323
#                           sedan                         53
# 190-class                 sedan                          3
# 2 series                  coupe                         32
# 200                       sedan                       3931
#                           convertible                  118
# 200sx                     coupe                         12
# 2500                      crew cab                     891
#                           mega cab                      23
#                           regular cab                   10
# ...

# %%
df_cat['body'].value_counts()
# Out:
# body
# sedan                      244235
# suv                        143844
# hatchback                   26238
# minivan                     25529
# coupe                       17752
# crew cab                    16394
# wagon                       16129
# convertible                 10476
# supercrew                    9033
# g sedan                      7417
# supercab                     5311
# regular cab                  4850
# van                          4528
# extended cab                 4507
# quad cab                     4095
# e-series van                 1823
# double cab                   1601
# g coupe                      1593
# crewmax cab                   565
# king cab                      532
# g convertible                 323
# genesis coupe                 294
# access cab                    294
# koup                          180
# club cab                      178
# cts coupe                     158
# mega cab                      111
# ...

# %%
make_list_body=df['body'].value_counts().index.tolist()
i=1
a=[]
for j in make_list_body:
    print(f'{i}--->  {j}')
    a.append(j)
    if i>=20:
        print('list finidh')
        break
    i=i+1
make_list_body=a
make_list_body= list(map(str.lower,make_list_body))
print(make_list_body)
print(len(make_list_body))
# Out:
# 1--->  sedan
# 2--->  suv
# 3--->  hatchback
# 4--->  minivan
# 5--->  coupe
# 6--->  crew cab
# 7--->  wagon
# 8--->  convertible
# 9--->  supercrew
# 10--->  g sedan
# 11--->  supercab
# 12--->  regular cab
# 13--->  van
# 14--->  extended cab
# 15--->  quad cab
# 16--->  e-series van
# 17--->  double cab
# 18--->  g coupe
# 19--->  crewmax cab
# 20--->  king cab
# list finidh
# ['sedan', 'suv', 'hatchback', 'minivan', 'coupe', 'crew cab', 'wagon', 'convertible', 'supercrew', 'g sedan', 'supercab', 'regular cab', 'van', 'extended cab', 'quad cab', 'e-series van', 'double cab', 'g coupe', 'crewmax cab', 'king cab']
# 20

# %%
print(make_list_body)
df_cat['body']=df_cat['body'].str.lower()
print(df_cat['body'].sample(5))
df_cat['body']=df_cat['body'].apply(lambda x: x  if x in make_list_body else 'other' )

print(df_cat['body'].nunique())
print(df_cat['body'].value_counts())
# Out:
# ['sedan', 'suv', 'hatchback', 'minivan', 'coupe', 'crew cab', 'wagon', 'convertible', 'supercrew', 'g sedan', 'supercab', 'regular cab', 'van', 'extended cab', 'quad cab', 'e-series van', 'double cab', 'g coupe', 'crewmax cab', 'king cab']
# 99712         suv
# 376424      sedan
# 280028      sedan
# 41983       sedan
# 102759    g sedan
# Name: body, dtype: object
# 21
# body
# sedan           244235
# suv             143844
# hatchback        26238
# minivan          25529
# coupe            17752
# crew cab         16394
# wagon            16129
# convertible      10476
# supercrew         9033
# g sedan           7417
# supercab          5311
# regular cab       4850
# van               4528
# extended cab      4507
# quad cab          4095
# other             2083
# e-series van      1823
# double cab        1601
# g coupe           1593
# crewmax cab        565
# king cab           532
# Name: count, dtype: int64

# %% [markdown]
# transmition me bs 3 value h to rehne do theek h banki pca to apply krna hi hoga age

# %%
df_cat['transmission'].value_counts()
# Out:
# transmission
# automatic    531434
# manual        17075
# sedan            26
# Name: count, dtype: int64

# %%
df_cat['color'].value_counts()
# Out:
# color
# black        109300
# white        104426
# silver        81960
# gray          81956
# blue          50106
# red           42811
# —             24592
# gold          11006
# green         10960
# beige          8998
# burgundy       8806
# brown          6640
# orange         2009
# purple         1526
# off-white      1421
# yellow         1237
# charcoal        473
# turquoise       225
# pink             42
# lime             15
# 4802              1
# 9410              1
# 1167              1
# 2172              1
# 14872             1
# 12655             1
# 15719             1
# 6388              1
# 16633             1
# 11034             1
# 2711              1
# 6864              1
# 339               1
# 18384             1
# 9887              1
# 9837              1
# 20379             1
# 20627             1
# 721               1
# 6158              1
# 2817              1
# 5705              1
# 18561             1
# 2846              1
# 9562              1
# ...

# %% [markdown]
# color me nan ki jgh _ a gya to usko hata ke nan bhar dungha and fir upper fill kr dunga

# %%
df_cat['color']=df_cat['color'].replace('—',np.nan)

# %%
df_cat['color']=df_cat['color'].fillna(method='bfill')
df_cat['color'].value_counts()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8756\3673145774.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cat['color']=df_cat['color'].fillna(method='bfill')
# color
# black        115021
# white        109913
# gray          86073
# silver        85375
# blue          52024
# red           44955
# green         11357
# gold          11209
# beige          9211
# burgundy       9129
# brown          6988
# orange         2118
# purple         1590
# off-white      1487
# yellow         1270
# charcoal        495
# turquoise       232
# pink             46
# lime             15
# 16633             2
# 4802              1
# 9410              1
# 1167              1
# 14872             1
# 2172              1
# 12655             1
# 15719             1
# 6388              1
# 11034             1
# 2711              1
# 6864              1
# 339               1
# 18384             1
# ...

# %%
make_list_color=df_cat['color'].value_counts().index.tolist()
i=1
a=[]
for j in make_list_color:
    print(f'{i}--->  {j}')
    a.append(j)
    if i>=15:
        print('list finidh')
        break
    i=i+1
make_list_color=a
make_list_color= list(map(str.lower,make_list_color))
print(make_list_color)
print(len(make_list_color))
# Out:
# 1--->  black
# 2--->  white
# 3--->  gray
# 4--->  silver
# 5--->  blue
# 6--->  red
# 7--->  green
# 8--->  gold
# 9--->  beige
# 10--->  burgundy
# 11--->  brown
# 12--->  orange
# 13--->  purple
# 14--->  off-white
# 15--->  yellow
# list finidh
# ['black', 'white', 'gray', 'silver', 'blue', 'red', 'green', 'gold', 'beige', 'burgundy', 'brown', 'orange', 'purple', 'off-white', 'yellow']
# 15

# %%
print(make_list_color)
df_cat['color']=df_cat['color'].str.lower()
print(df_cat['color'].sample(5))
df_cat['color']=df_cat['color'].apply(lambda x: x  if x in make_list_color else 'other' )

print(df_cat['color'].nunique())
print(df_cat['color'].value_counts())
# Out:
# ['black', 'white', 'gray', 'silver', 'blue', 'red', 'green', 'gold', 'beige', 'burgundy', 'brown', 'orange', 'purple', 'off-white', 'yellow']
# 461545    silver
# 30018     silver
# 510547     black
# 412881     white
# 249053      gray
# Name: color, dtype: object
# 16
# color
# black        115021
# white        109913
# gray          86073
# silver        85375
# blue          52024
# red           44955
# green         11357
# gold          11209
# beige          9211
# burgundy       9129
# brown          6988
# orange         2118
# purple         1590
# off-white      1487
# yellow         1270
# other           815
# Name: count, dtype: int64

# %% [markdown]
# now start opration for state

# %%
df_cat['state'].value_counts()
# Out:
# state
# fl                   81482
# ca                   71667
# pa                   53158
# tx                   45196
# ga                   34059
# nj                   27365
# il                   23196
# nc                   21333
# oh                   21252
# tn                   20691
# mo                   15798
# mi                   15287
# nv                   12453
# va                   11696
# md                   10842
# wi                    9704
# mn                    9301
# az                    8576
# co                    7661
# wa                    7257
# ma                    6525
# ny                    5609
# in                    4273
# sc                    4146
# ne                    3954
# on                    3008
# pr                    2673
# la                    2164
# ms                    1814
# ut                    1798
# hi                    1222
# or                    1136
# qc                    1108
# ab                     801
# ...

# %%
make_list_state=df_cat['state'].value_counts().index.tolist()
i=1
a=[]
for j in make_list_state:
    print(f'{i}--->  {j}')
    a.append(j)
    if i>=35:
        print('list finidh')
        break
    i=i+1
make_list_state=a
make_list_state= list(map(str.lower,make_list_state))
print(make_list_state)
print(len(make_list_state))
# Out:
# 1--->  fl
# 2--->  ca
# 3--->  pa
# 4--->  tx
# 5--->  ga
# 6--->  nj
# 7--->  il
# 8--->  nc
# 9--->  oh
# 10--->  tn
# 11--->  mo
# 12--->  mi
# 13--->  nv
# 14--->  va
# 15--->  md
# 16--->  wi
# 17--->  mn
# 18--->  az
# 19--->  co
# 20--->  wa
# 21--->  ma
# 22--->  ny
# 23--->  in
# 24--->  sc
# 25--->  ne
# 26--->  on
# 27--->  pr
# 28--->  la
# 29--->  ms
# 30--->  ut
# 31--->  hi
# 32--->  or
# 33--->  qc
# 34--->  ab
# 35--->  nm
# list finidh
# ['fl', 'ca', 'pa', 'tx', 'ga', 'nj', 'il', 'nc', 'oh', 'tn', 'mo', 'mi', 'nv', 'va', 'md', 'wi', 'mn', 'az', 'co', 'wa', 'ma', 'ny', 'in', 'sc', 'ne', 'on', 'pr', 'la', 'ms', 'ut', 'hi', 'or', 'qc', 'ab', 'nm']
# 35

# %%
print(make_list_state)
df_cat['state']=df_cat['state'].str.lower()
print(df_cat['state'].sample(5))
df_cat['state']=df_cat['state'].apply(lambda x: x  if x in make_list_state else 'other' )

print(df_cat['state'].nunique())
print(df_cat['state'].value_counts())
# Out:
# ['fl', 'ca', 'pa', 'tx', 'ga', 'nj', 'il', 'nc', 'oh', 'tn', 'mo', 'mi', 'nv', 'va', 'md', 'wi', 'mn', 'az', 'co', 'wa', 'ma', 'ny', 'in', 'sc', 'ne', 'on', 'pr', 'la', 'ms', 'ut', 'hi', 'or', 'qc', 'ab', 'nm']
# 143558    il
# 47832     fl
# 248064    pa
# 42847     fl
# 381137    mi
# Name: state, dtype: object
# 36
# state
# fl       81482
# ca       71667
# pa       53158
# tx       45196
# ga       34059
# nj       27365
# il       23196
# nc       21333
# oh       21252
# tn       20691
# mo       15798
# mi       15287
# nv       12453
# va       11696
# md       10842
# wi        9704
# mn        9301
# az        8576
# co        7661
# wa        7257
# ma        6525
# ny        5609
# in        4273
# sc        4146
# ne        3954
# on        3008
# pr        2673
# la        2164
# ms        1814
# ut        1798
# hi        1222
# or        1136
# qc        1108
# ab         801
# other      166
# nm         164
# Name: count, dtype: int64

# %% [markdown]
# now interior k bari
# \

# %%
df_cat['interior'].value_counts()
# Out:
# interior
# black        241298
# gray         174741
# beige         58679
# tan           43162
# —             16738
# brown          8474
# red            1329
# silver         1083
# blue           1070
# off-white       485
# purple          333
# gold            315
# white           251
# green           234
# burgundy        187
# orange          136
# yellow           20
# Name: count, dtype: int64

# %%
df_cat['interior']=df_cat['interior'].replace('—',np.nan)
df_cat['interior']=df_cat['interior'].fillna(method='bfill')
df_cat['interior'].value_counts()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8756\62148182.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cat['interior']=df_cat['interior'].fillna(method='bfill')
# interior
# black        247755
# gray         180898
# beige         60554
# tan           44882
# brown          8788
# red            1381
# silver         1125
# blue           1123
# off-white       498
# purple          347
# gold            330
# white           258
# green           243
# burgundy        190
# orange          142
# yellow           21
# Name: count, dtype: int64

# %% [markdown]
# ab dfcat ke sb column ko df me dakuna h

# %%
df_cat.head(2)
# Out:
#   make    model trim body transmission state  color interior
# 0  kia  sorento   lx  suv    automatic    ca  white    black
# 1  kia  sorento   lx  suv    automatic    ca  white    beige

# %%
df[['make'	,'model'	,'trim',	'body'	,'transmission',	'state'	,'color',	'interior']]=df_cat[['make'	,'model'	,'trim',	'body'	,'transmission',	'state'	,'color',	'interior']]

# %%
df['trim'].value_counts()
# Out:
# trim
# other          176000
# base            55916
# se              43694
# lx              20788
# limited         18371
# lt              17023
# xlt             16745
# ls              13539
# le              12929
# gls             12336
# s               12280
# 2.5 s           11212
# sxt             11206
# touring         11152
# sel             10480
# sport            9688
# ex               9511
# 2.5              6908
# slt              6014
# sv               5700
# ex-l             5385
# ltz              5286
# xl               4205
# g37x             4172
# v6               3964
# 3.5 sv           3629
# sl               3520
# 328i             3420
# lariat           3395
# titanium         3025
# 1lt              2907
# g37 journey      2902
# lt fleet         2755
# laredo           2747
# ls fleet         2361
# sle              2350
# luxury           2332
# se pzev          2323
# gt               2154
# premium          2114
# 2lt              2097
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548535 entries, 0 to 548534
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          548535 non-null  int64
#  1   make          548535 non-null  object
#  2   model         548535 non-null  object
#  3   trim          548535 non-null  object
#  4   body          548535 non-null  object
#  5   transmission  548535 non-null  object
#  6   state         548535 non-null  object
#  7   condition     548535 non-null  float64
#  8   odometer      548535 non-null  float64
#  9   color         548535 non-null  object
#  10  interior      548535 non-null  object
#  11  seller        548535 non-null  object
#  12  mmr           548535 non-null  float64
#  13  sellingprice  548535 non-null  float64
#  14  saledate      548535 non-null  object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 62.8+ MB

# %%
def target_encode(df, cat_col, target_col='sellingprice'):
    target_mean = df.groupby(cat_col)[target_col].mean()
    return df[cat_col].map(target_mean)

for col in df.select_dtypes(include='object'):
    df[col + '_target'] = target_encode(df, col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548535 entries, 0 to 548534
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 548535 non-null  int64
#  1   make                 548535 non-null  object
#  2   model                548535 non-null  object
#  3   trim                 548535 non-null  object
#  4   body                 548535 non-null  object
#  5   transmission         548535 non-null  object
#  6   state                548535 non-null  object
#  7   condition            548535 non-null  float64
#  8   odometer             548535 non-null  float64
#  9   color                548535 non-null  object
#  10  interior             548535 non-null  object
#  11  seller               548535 non-null  object
#  12  mmr                  548535 non-null  float64
#  13  sellingprice         548535 non-null  float64
# ...

# %%
# Sirf numerical columns ke correlation ke liye
corr_matrix = df.corr(numeric_only=True)

# Table print karne ke liye
corr_matrix
# Out:
#                          year  condition  odometer       mmr  sellingprice  \
# year                 1.000000   0.344360 -0.775077  0.595557      0.585388
# condition            0.344360   1.000000 -0.319697  0.282726      0.322527
# odometer            -0.775077  -0.319697  1.000000 -0.586155     -0.580442
# mmr                  0.595557   0.282726 -0.586155  1.000000      0.983599
# sellingprice         0.585388   0.322527 -0.580442  0.983599      1.000000
# make_target          0.033155   0.114169 -0.086456  0.423537      0.419095
# model_target         0.203474   0.167522 -0.190398  0.672268      0.665097
# trim_target         -0.024515   0.053671 -0.008757  0.275054      0.272751
# body_target         -0.006436   0.073867  0.014697  0.321780      0.320078
# transmission_target  0.084898   0.020271 -0.031337  0.043880      0.045987
# state_target         0.212513   0.111337 -0.235789  0.217831      0.224517
# ...

# %%
df.head(3)
# Out:
#    year make     model   trim   body transmission state  condition  odometer  \
# 0  2015  kia   sorento     lx    suv    automatic    ca        5.0   16639.0
# 1  2015  kia   sorento     lx    suv    automatic    ca        5.0    9393.0
# 2  2014  bmw  3 series  other  sedan    automatic    ca       45.0    1331.0
#
#    color  ...   make_target  model_target   trim_target   body_target  \
# 0  white  ...  11806.384655  14643.257923  10277.055251  16115.916681
# 1  white  ...  11806.384655  14643.257923  10277.055251  16115.916681
# 2   gray  ...  21474.030347  17374.273824  15176.603284  11662.030172
#
#   transmission_target  state_target  color_target  interior_target  \
# 0        13778.744466  14544.230971  15061.777730     15706.267077
# 1        13778.744466  14544.230971  15061.777730     13328.382056
# 2        13778.744466  14544.230971  14181.824215     15706.267077
#
#    seller_target  saledate_target
# 0   16122.995733     15000.455927
# ...

# %%
# from ydata_profiling import ProfileReport
# profile = ProfileReport(df, title="My Data Report", explorative=True)
# profile.to_file("report.html")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548535 entries, 0 to 548534
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 548535 non-null  int64
#  1   make                 548535 non-null  object
#  2   model                548535 non-null  object
#  3   trim                 548535 non-null  object
#  4   body                 548535 non-null  object
#  5   transmission         548535 non-null  object
#  6   state                548535 non-null  object
#  7   condition            548535 non-null  float64
#  8   odometer             548535 non-null  float64
#  9   color                548535 non-null  object
#  10  interior             548535 non-null  object
#  11  seller               548535 non-null  object
#  12  mmr                  548535 non-null  float64
#  13  sellingprice         548535 non-null  float64
# ...

# %%
df_num=df.select_dtypes(include='float')
df_num.sample(2)
# Out:
#         condition  odometer      mmr  sellingprice   make_target  \
# 304523       38.0   30890.0  19500.0       18000.0  16923.403835
# 167029       41.0   37259.0  17100.0       16700.0  15072.469655
#
#         model_target   trim_target   body_target  transmission_target  \
# 304523  17450.616197  15176.603284  16115.916681         13778.744466
# 167029  10766.975698  13864.638656  11662.030172         13778.744466
#
#         state_target  color_target  interior_target  seller_target  \
# 304523  16039.238177  15745.324198     11023.553637   15186.820218
# 167029  14493.077546  15745.324198     15706.267077   20064.997537
#
#         saledate_target
# 304523     16596.051856
# 167029     13440.071367

# %%
df.sample(2
          )
# Out:
#         year  make  model   trim   body transmission state  condition  \
# 324357  2014  ford   edge     se    suv    automatic    pa        5.0
# 427450  2008  ford  focus  other  sedan    automatic    oh       29.0
#
#         odometer   color  ...   make_target  model_target   trim_target  \
# 324357   11593.0   white  ...  14496.109243  18743.485883  11214.052870
# 427450   67616.0  silver  ...  14496.109243   9314.311568  15176.603284
#
#          body_target transmission_target  state_target  color_target  \
# 324357  16115.916681        13778.744466  16039.238177  15061.777730
# 427450  11662.030172        13778.744466  14493.077546  12058.291762
#
#         interior_target  seller_target  saledate_target
# 324357     11023.553637   14900.000000     13175.617284
# 427450     11023.553637    2706.859155     12166.952055
#
# [2 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate', 'make_target', 'model_target',
#        'trim_target', 'body_target', 'transmission_target', 'state_target',
#        'color_target', 'interior_target', 'seller_target', 'saledate_target'],
#       dtype='object')

# %%
df_final=df[['year','make','model','body','seller','condition','odometer','mmr','sellingprice']]
df_final.to_csv('final step data.csv',index=False)

# %%
# df_num.describe()

# %%
# %matplotlib inline
# for col in df_num:
#     plt.boxplot(df_num[col])
#     plt.xlabel(col)
#     plt.show()
